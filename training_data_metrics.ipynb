# %%
import pandas as pd
import zipfile

# %%
year = 2020
panda_label_num = 0

# %% [markdown]
# ### Match panda labels to their record IDs
#
# The panda labels use columns `id_l` and `id_r` where `id_l` corresponds
# to the `id` column in the FERC data and `id_r` corresponds to the
# index in the EIA input data.

# %%
panda_labels = pd.read_csv(f"panda_matches/panda_label_{panda_label_num}.csv")

# %%
input_zip = zipfile.ZipFile(f"panda_inputs/{year}.zip")
ferc_input = pd.read_csv(input_zip.open("left.csv"))
eia_input = pd.read_csv(input_zip.open("right.csv"))

# %%
panda_labels = panda_labels.join(ferc_input.set_index("id")["record_id_ferc1"], on="id_l")
panda_labels = panda_labels.join(eia_input["record_id_eia"], on="id_r")

# %%
panda_labels
# Out:
#         id_l   id_r  panda_label  panda_soft_label           record_id_ferc1  \
# 0      27884  23861           -1      9.165326e-15  f1_steam_2020_12_144_1_4
# 1      27884  23862           -1      9.165326e-15  f1_steam_2020_12_144_1_4
# 2      27771  32223           -1      9.165326e-15  f1_steam_2020_12_164_1_1
# 3      27771  32224           -1      9.165326e-15  f1_steam_2020_12_164_1_1
# 4      27771  32225           -1      9.165326e-15  f1_steam_2020_12_164_1_1
# ...      ...    ...          ...               ...                       ...
# 20146  28273  17335            1      9.983238e-01   f1_steam_2020_12_44_0_5
# 20147  27571  20806            1      1.000000e+00  f1_steam_2020_12_176_1_5
# 20148  27727   2167           -1      2.575863e-14   f1_steam_2020_12_57_1_5
# 20149  27718   2161            1      9.999991e-01   f1_steam_2020_12_57_0_1
# 20150  28252   9786            1      9.768642e-01   f1_steam_2020_12_17_3_4
#
#                                      record_id_eia
# 0                 235_1_2020_plant_gen_total_14328
# 1                 235_2_2020_plant_gen_total_14328
# 2                 7538_1_2020_plant_gen_total_3046
# 3                 7538_2_2020_plant_gen_total_3046
# 4                 7538_3_2020_plant_gen_total_3046
# ...                                            ...
# 20146            6035_1_2020_plant_unit_total_5109
# 20147  59784_ct_2020_plant_prime_mover_total_24211
# 20148            708_2020_plant_total_7140_retired
# 20149                    703_2020_plant_total_7140
# 20150                  58215_2020_plant_total_3046
#
# [20151 rows x 6 columns]

# %% [markdown]
# ### Find the percentage of labeled training data that Panda finds
#
# Note: the input EIA data to Panda is distinct, meaning that only true gran records are included. I'm not sure if the training labels are exclusive to true gran records.

# %%
training_labels = pd.read_csv("train_ferc1_eia.csv")

# %%
concat_labels = pd.concat(
    [panda_labels[["record_id_eia", "record_id_ferc1"]], training_labels[["record_id_eia", "record_id_ferc1"]]])

# %%
finds = concat_labels[concat_labels.duplicated()]

# %%
# this is maybe not the complete 2020 training data, need to verify with CG
train_labels_2020 = pd.read_csv("train_ferc1_eia_2020.csv")

# %%
len(finds), len(train_labels_2020), len(finds)/len(train_labels_2020)
# Out:
# (115, 119, 0.9663865546218487)

# %% [markdown]
# ### Look at the matches that Panda didn't find
#
# See note above about input EIA data only being the true gran records. Seems like that's why one of the missed records isn't even in the EIA input data.

# %%
finds_and_labels = pd.concat([finds, train_labels_2020[["record_id_eia", "record_id_ferc1"]]])
misses = finds_and_labels.drop_duplicates(keep=False)

# %%
misses
# Out:
#                           record_id_eia           record_id_ferc1
# 2     113_4_2020_plant_unit_total_14354  f1_steam_2020_12_134_0_1
# 3   2322_gt4_2020_plant_gen_total_13407  f1_steam_2020_12_108_1_1
# 25         55322_2020_plant_total_13407  f1_steam_2020_12_108_2_2
# 28         10761_2020_plant_total_13407  f1_steam_2020_12_108_0_1

# %% [markdown]
# Look at the Panda soft value for these misses.
#
# Since there is Nan in the pandas soft label, it seems like these records were not part of the candidate set. Off the top of my head I forget why Panda excludes some records from the candidate set.

# %%
misses.join(
    panda_labels.set_index(
        ["record_id_eia", "record_id_ferc1"])[["panda_soft_label"]],\
    on=["record_id_eia", "record_id_ferc1"])
# Out:
#                           record_id_eia           record_id_ferc1  \
# 2     113_4_2020_plant_unit_total_14354  f1_steam_2020_12_134_0_1
# 3   2322_gt4_2020_plant_gen_total_13407  f1_steam_2020_12_108_1_1
# 25         55322_2020_plant_total_13407  f1_steam_2020_12_108_2_2
# 28         10761_2020_plant_total_13407  f1_steam_2020_12_108_0_1
#
#     panda_soft_label
# 2                NaN
# 3                NaN
# 25               NaN
# 28               NaN

# %% [markdown]
# Look at the full EIA and FERC records for these missed pairs.

# %%
# join on the EIA and FERC data
misses_full = misses.join(
    eia_input.set_index("record_id_eia"), on="record_id_eia").join(
    ferc_input.set_index("record_id_ferc1"), on="record_id_ferc1", lsuffix="_eia", rsuffix="_ferc1")

# %%
# sort the non id columns of the joined dataframe to make easier comparison between columns
non_id_df = misses_full[misses_full.columns.difference(["record_id_eia", "record_id_ferc1"])]

misses_full = pd.concat([misses_full[["record_id_eia", "record_id_ferc1"]],
           non_id_df.reindex(sorted(non_id_df.columns), axis=1)], axis=1)

# %%
misses_full
# Out:
#                           record_id_eia           record_id_ferc1  \
# 2     113_4_2020_plant_unit_total_14354  f1_steam_2020_12_134_0_1
# 3   2322_gt4_2020_plant_gen_total_13407  f1_steam_2020_12_108_1_1
# 25         55322_2020_plant_total_13407  f1_steam_2020_12_108_2_2
# 28         10761_2020_plant_total_13407  f1_steam_2020_12_108_0_1
#
#    appro_part_label                  appro_record_id_eia  capacity_eoy_mw  \
# 2               NaN                                  NaN              NaN
# 3         plant_gen  2322_gt4_2020_plant_gen_total_13407             72.4
# 25            plant         55322_2020_plant_total_13407           1465.6
# 28            plant         10761_2020_plant_total_13407            358.9
#
#     capacity_factor_eia  capacity_factor_ferc1  capacity_mw_eia  \
# 2                   NaN               0.460336              NaN
# 3                   NaN               0.017254             72.4
# 25             0.475715               0.477485           1465.6
# 28             0.100082               0.100578            358.9
#
#     capacity_mw_ferc1 construction_type  ...  total_fuel_cost_ferc1  \
# 2               414.0           outdoor  ...           4.892805e+07
# 3                72.4      conventional  ...           3.295083e+05
# 25             1465.4       semioutdoor  ...           1.212211e+08
# 28              358.8           outdoor  ...           7.403684e+06
#
#     total_mmbtu_eia total_mmbtu_ferc1 true_gran  unit_id_pudl  utility_id_eia  \
# 2               NaN      1.875294e+07       NaN           NaN             NaN
# 3               NaN      1.624169e+05      True           NaN         13407.0
# 25      45715668.40      4.689478e+07      True           NaN         13407.0
# 28       2785333.39      2.919426e+06      True           NaN         13407.0
#
#     utility_id_pudl_eia  utility_id_pudl_ferc1  utility_name_eia  \
# 2                   NaN                    246               NaN
# 3                 204.0                    204   Nevada Power Co
# 25                204.0                    204   Nevada Power Co
# 28                204.0                    204   Nevada Power Co
#
#                        utility_name_ferc1
# 2                              PacifiCorp
# 3   Nevada Power Company, d/b/a NV Energy
# 25  Nevada Power Company, d/b/a NV Energy
# 28  Nevada Power Company, d/b/a NV Energy
#
# [4 rows x 69 columns]

# %% [markdown]
# Compare the primary string columns.

# %%
misses_full[[
    "plant_name_eia", "plant_name_ferc1", 
    "utility_name_eia", "utility_name_ferc1", 
    "energy_source_code_1", "technology_description",
    "fuel_type_code_pudl_eia", "fuel_type_code_pudl_ferc1"]]
# Out:
#            plant_name_eia plant_name_ferc1 utility_name_eia  \
# 2                     NaN           cholla              NaN
# 3                   Clark          clark 4  Nevada Power Co
# 25  Moapa Energy Facility     lenzie 1 & 2  Nevada Power Co
# 28        Las Vegas Cogen    lv generation  Nevada Power Co
#
#                        utility_name_ferc1 energy_source_code_1  \
# 2                              PacifiCorp                  NaN
# 3   Nevada Power Company, d/b/a NV Energy                   NG
# 25  Nevada Power Company, d/b/a NV Energy                   NG
# 28  Nevada Power Company, d/b/a NV Energy                   NG
#
#                   technology_description fuel_type_code_pudl_eia  \
# 2                                    NaN                     NaN
# 3   Natural Gas Fired Combustion Turbine                     gas
# 25      Natural Gas Fired Combined Cycle                     gas
# 28      Natural Gas Fired Combined Cycle                     gas
#
#    fuel_type_code_pudl_ferc1
# 2                       coal
# 3                        gas
# 25                       gas
# 28                       gas

# %% [markdown]
# Compare some of the numeric columns.

# %%
misses_full[[
    'construction_year_eia', 'construction_year_ferc1', 
    'installation_year_eia', 'installation_year_ferc1']]
# Out:
#     construction_year_eia  construction_year_ferc1  installation_year_eia  \
# 2                     NaN                   1981.0                    NaN
# 3                  1973.0                   1973.0                 1973.0
# 25                 2006.0                   2005.0                 2006.0
# 28                 1994.0                   1994.0                 2003.0
#
#     installation_year_ferc1
# 2                    1981.0
# 3                    1973.0
# 25                   2006.0
# 28                   2002.0

# %%
cols = ['capacity_factor_eia',
       'capacity_factor_ferc1', 
       'capacity_mw_eia', 
       'capacity_mw_ferc1',
       'fuel_cost_per_mmbtu_eia', 'fuel_cost_per_mmbtu_ferc1',
       'fuel_cost_per_mwh_eia', 'fuel_cost_per_mwh_ferc1',
       'fuel_type_code_pudl_eia', 'fuel_type_code_pudl_ferc1',
       'heat_rate_mmbtu_mwh_eia', 'heat_rate_mmbtu_mwh_ferc1',
       'net_generation_mwh_eia', 'net_generation_mwh_ferc1']
misses_full[cols]
# Out:
#     capacity_factor_eia  capacity_factor_ferc1  capacity_mw_eia  \
# 2                   NaN               0.460336              NaN
# 3                   NaN               0.017254             72.4
# 25             0.475715               0.477485           1465.6
# 28             0.100082               0.100578            358.9
#
#     capacity_mw_ferc1  fuel_cost_per_mmbtu_eia  fuel_cost_per_mmbtu_ferc1  \
# 2               414.0                      NaN                   2.609087
# 3                72.4                      NaN                   2.028781
# 25             1465.4                 2.659401                   2.584960
# 28              358.8                 2.572691                   2.536007
#
#     fuel_cost_per_mwh_eia  fuel_cost_per_mwh_ferc1 fuel_type_code_pudl_eia  \
# 2                     NaN                29.307521                     NaN
# 3                     NaN                30.106735                     gas
# 25              19.866597                19.776492                     gas
# 28              22.677536                23.416055                     gas
#
#    fuel_type_code_pudl_ferc1  heat_rate_mmbtu_mwh_eia  \
# 2                       coal                      NaN
# 3                        gas                      NaN
# 25                       gas                 7.470327
# 28                       gas                 8.814714
#
#     heat_rate_mmbtu_mwh_ferc1  net_generation_mwh_eia  \
# 2                   11.232844                     NaN
# 3                   14.842085                     NaN
# 25                   7.650750               6124268.0
# 28                   9.235021                315516.0
#
#     net_generation_mwh_ferc1
# 2                 1669474.00
# 3                   10943.00
# 25                6129435.16
# 28                 316125.50
